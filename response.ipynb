# %%
import pandas as pd

results = pd.read_csv('./model_evaluation/RandomForest.csv')
results
# Out:
#   Unnamed: 0    jruby@2     hive@1    camel@0     hive@0    camel@1  \
# 0    AUC-ROC   0.783574   0.649617   0.709668   0.615411   0.768081
# 1   F1-score   0.316547   0.220065   0.253700   0.431694   0.350711
# 2  Precision   0.415094   0.278689   0.200669   0.355856   0.440476
# 3     Recall   0.255814   0.181818   0.344828   0.548611   0.291339
# 4         TP   0.255814   0.181818   0.344828   0.548611   0.291339
# 5    # of TP  22.000000  34.000000  60.000000  79.000000  37.000000
#
#    activemq@3  activemq@2  lucene@2     derby@0  ...     hbase@1     hbase@0  \
# 0    0.767666    0.765598  0.732851    0.853651  ...    0.693625    0.691593
# 1    0.392060    0.543624  0.086957    0.645897  ...    0.505824    0.421875
# 2    0.376190    0.618321  0.153846    0.637181  ...    0.571429    0.617143
# 3    0.409326    0.485030  0.060606    0.654854  ...    0.453731    0.320475
# 4    0.409326    0.485030  0.060606    0.654854  ...    0.453731    0.320475
# ...

# %%
results = pd.read_csv('./model_evaluation/LogisticRegression.csv')
results
# Out:
#   Unnamed: 0    jruby@2     hive@1    camel@0     hive@0    camel@1  \
# 0    AUC-ROC   0.744593   0.574799   0.668457   0.645288   0.750208
# 1   F1-score   0.378378   0.166065   0.235616   0.424615   0.209302
# 2  Precision   0.451613   0.255556   0.225131   0.381215   0.400000
# 3     Recall   0.325581   0.122995   0.247126   0.479167   0.141732
# 4         TP   0.325581   0.122995   0.247126   0.479167   0.141732
# 5    # of TP  28.000000  23.000000  43.000000  69.000000  18.000000
#
#    activemq@3  activemq@2  lucene@2     derby@0  ...     hbase@1     hbase@0  \
# 0    0.747208    0.742154  0.628833    0.795092  ...    0.692211    0.680485
# 1    0.356688    0.458333  0.123457    0.578947  ...    0.506422    0.430380
# 2    0.302158    0.753425  0.333333    0.620811  ...    0.657143    0.550926
# 3    0.435233    0.329341  0.075758    0.542373  ...    0.411940    0.353116
# 4    0.435233    0.329341  0.075758    0.542373  ...    0.411940    0.353116
# ...

# %%
results = pd.read_csv('./model_evaluation/XGBoost.csv')
results
# Out:
#   Unnamed: 0    jruby@2     hive@1    camel@0     hive@0    camel@1  \
# 0    AUC-ROC   0.745036   0.629905   0.648619   0.607441   0.764891
# 1   F1-score   0.310811   0.260536   0.168040   0.434109   0.325359
# 2  Precision   0.370968   0.202985   0.117783   0.345679   0.414634
# 3     Recall   0.267442   0.363636   0.293103   0.583333   0.267717
# 4         TP   0.267442   0.363636   0.293103   0.583333   0.267717
# 5    # of TP  23.000000  68.000000  51.000000  84.000000  34.000000
#
#    activemq@3  activemq@2  lucene@2     derby@0  ...     hbase@1     hbase@0  \
# 0    0.729829    0.740809  0.705736    0.831675  ...    0.664155    0.671238
# 1    0.314685    0.529412  0.088496    0.650566  ...    0.519440    0.375465
# 2    0.237467    0.520231  0.106383    0.637574  ...    0.542208    0.502488
# 3    0.466321    0.538922  0.075758    0.664099  ...    0.498507    0.299703
# 4    0.466321    0.538922  0.075758    0.664099  ...    0.498507    0.299703
# ...

# %%
results = pd.read_csv('./model_evaluation/SVM.csv')
results
# Out:
#   Unnamed: 0   jruby@2     hive@1    camel@0     hive@0   camel@1  activemq@3  \
# 0    AUC-ROC  0.670240   0.547669   0.727827   0.691000  0.605636    0.691530
# 1   F1-score  0.130435   0.112069   0.277778   0.247191  0.088235    0.272727
# 2  Precision  1.000000   0.288889   0.247748   0.647059  0.666667    0.507042
# 3     Recall  0.069767   0.069519   0.316092   0.152778  0.047244    0.186528
# 4         TP  0.069767   0.069519   0.316092   0.152778  0.047244    0.186528
# 5    # of TP  6.000000  13.000000  55.000000  22.000000  6.000000   36.000000
#
#    activemq@2  lucene@2     derby@0  ...    hbase@1   hbase@0   camel@2  \
# 0    0.735346  0.603789    0.765791  ...   0.713417  0.678012  0.659038
# 1    0.344498  0.029851    0.509126  ...   0.221649  0.051429  0.057143
# 2    0.857143  1.000000    0.676020  ...   0.811321  0.692308  0.750000
# 3    0.215569  0.015152    0.408320  ...   0.128358  0.026706  0.029703
# ...
